# %% [markdown]
# # FE800 Final Project - Deep hedging

# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Heston Model

# %% [markdown]
# ### Load TRPO Learning Curves

# %%
lc_trpo_0_90_H = pd.read_csv("./HestonModel/models/TRPO_25_90/learning_curve.csv")
lc_trpo_0_30_H = pd.read_csv("./HestonModel/models/TRPO_25_30/learning_curve.csv")
lc_trpo_0_15_H = pd.read_csv("./HestonModel/models/TRPO_25_15/learning_curve.csv")
lc_trpo_1_90_H = pd.read_csv("./HestonModel/models/TRPO_50_90/learning_curve.csv")
lc_trpo_1_30_H = pd.read_csv("./HestonModel/models/TRPO_50_30/learning_curve.csv")
lc_trpo_1_15_H = pd.read_csv("./HestonModel/models/TRPO_50_15/learning_curve.csv")
lc_trpo_2_90_H = pd.read_csv("./HestonModel/models/TRPO_75_90/learning_curve.csv")
lc_trpo_2_30_H = pd.read_csv("./HestonModel/models/TRPO_75_30/learning_curve.csv")
lc_trpo_2_15_H = pd.read_csv("./HestonModel/models/TRPO_75_15/learning_curve.csv")
lc_trpo_3_90_H = pd.read_csv("./HestonModel/models/TRPO_100_90/learning_curve.csv")
lc_trpo_3_30_H = pd.read_csv("./HestonModel/models/TRPO_100_30/learning_curve.csv")
lc_trpo_3_15_H = pd.read_csv("./HestonModel/models/TRPO_100_15/learning_curve.csv")
lc_trpo_0_90_H.head()
# Out:
#    Number of Episodes     Rewards
# 0                4500 -134.700629
# 1                4590 -133.493666
# 2                4680 -133.148589
# 3                4770 -132.626074
# 4                4860 -133.446596

# %% [markdown]
# ### Plot TRPO Learning Curves

# %%
fig, ((ax_1_90, ax_2_90, ax_3_90), 
      (ax_1_30, ax_2_30, ax_3_30),
      (ax_1_15, ax_2_15, ax_3_15)) = plt.subplots(3, 3, sharex=True, sharey=True, figsize = (16,10))

# sns.lineplot(data=lc_trpo_0_90_H, x="Number of Episodes", y="Rewards", ax=ax_0_90)
# sns.lineplot(data=lc_trpo_0_30_H, x="Number of Episodes", y="Rewards", ax=ax_0_30)
# sns.lineplot(data=lc_trpo_0_15_H, x="Number of Episodes", y="Rewards", ax=ax_0_15)
sns.lineplot(data=lc_trpo_1_90_H, x="Number of Episodes", y="Rewards", ax=ax_1_90)
sns.lineplot(data=lc_trpo_1_30_H, x="Number of Episodes", y="Rewards", ax=ax_1_30)
sns.lineplot(data=lc_trpo_1_15_H, x="Number of Episodes", y="Rewards", ax=ax_1_15)
sns.lineplot(data=lc_trpo_2_90_H, x="Number of Episodes", y="Rewards", ax=ax_2_90)
sns.lineplot(data=lc_trpo_2_30_H, x="Number of Episodes", y="Rewards", ax=ax_2_30)
sns.lineplot(data=lc_trpo_2_15_H, x="Number of Episodes", y="Rewards", ax=ax_2_15)
sns.lineplot(data=lc_trpo_3_90_H, x="Number of Episodes", y="Rewards", ax=ax_3_90)
sns.lineplot(data=lc_trpo_3_30_H, x="Number of Episodes", y="Rewards", ax=ax_3_30)
sns.lineplot(data=lc_trpo_3_15_H, x="Number of Episodes", y="Rewards", ax=ax_3_15)
# Out:
# <AxesSubplot:xlabel='Number of Episodes', ylabel='Rewards'>

# %% [markdown]
# ### Plot Sample TRPO Learning Curve

# %%
title='Learning Curve'
fig = plt.figure(title)
plt.figure(figsize=(8,5))
plt.plot(lc_trpo_1_30_H["Number of Episodes"], lc_trpo_1_30_H["Rewards"])
plt.xlabel('Number of Episodes')
plt.ylabel('Rewards')
plt.title(title + " Smoothed", fontsize=20)
plt.show()

# %% [markdown]
# ### Load Test Path for Delta agent

# %%
run_delta_0_90_H = pd.read_csv("./HestonModel/models/DELTA_25_90/test_run.csv")
run_delta_0_30_H = pd.read_csv("./HestonModel/models/DELTA_25_30/test_run.csv")
run_delta_0_15_H = pd.read_csv("./HestonModel/models/DELTA_25_15/test_run.csv")
run_delta_1_90_H = pd.read_csv("./HestonModel/models/DELTA_50_90/test_run.csv")
run_delta_1_30_H = pd.read_csv("./HestonModel/models/DELTA_50_30/test_run.csv")
run_delta_1_15_H = pd.read_csv("./HestonModel/models/DELTA_50_15/test_run.csv")
run_delta_2_90_H = pd.read_csv("./HestonModel/models/DELTA_75_90/test_run.csv")
run_delta_2_30_H = pd.read_csv("./HestonModel/models/DELTA_75_30/test_run.csv")
run_delta_2_15_H = pd.read_csv("./HestonModel/models/DELTA_75_15/test_run.csv")
run_delta_0_90_H.head()
# Out:
#        time     price    action
# 0  0.000000  1.000000  0.562816
# 1  0.002809  0.983650  0.520890
# 2  0.005618  1.004475  0.573348
# 3  0.008427  1.019824  0.610925
# 4  0.011236  1.008780  0.583603

# %% [markdown]
# ### Load Test Path for TRPO agent

# %%
run_trpo_0_90_H = pd.read_csv("./HestonModel/models/TRPO_25_90/test_run.csv")
run_trpo_0_30_H = pd.read_csv("./HestonModel/models/TRPO_25_30/test_run.csv")
run_trpo_0_15_H = pd.read_csv("./HestonModel/models/TRPO_25_15/test_run.csv")
run_trpo_1_90_H = pd.read_csv("./HestonModel/models/TRPO_50_90/test_run.csv")
run_trpo_1_30_H = pd.read_csv("./HestonModel/models/TRPO_50_30/test_run.csv")
run_trpo_1_15_H = pd.read_csv("./HestonModel/models/TRPO_50_15/test_run.csv")
run_trpo_2_90_H = pd.read_csv("./HestonModel/models/TRPO_75_90/test_run.csv")
run_trpo_2_30_H = pd.read_csv("./HestonModel/models/TRPO_75_30/test_run.csv")
run_trpo_2_15_H = pd.read_csv("./HestonModel/models/TRPO_75_15/test_run.csv")
run_trpo_0_90_H.head()
# Out:
#        time     price    action
# 0  0.000000  1.000000  0.577985
# 1  0.002809  0.983650  0.510050
# 2  0.005618  1.004475  0.559251
# 3  0.008427  1.019824  0.602379
# 4  0.011236  1.008780  0.576351

# %% [markdown]
# ### Plot Hedging Actions for Delta vs TRPO agent

# %%
fig, ((ax_0_90, ax_1_90, ax_2_90), 
      (ax_0_30, ax_1_30, ax_2_30),
      (ax_0_15, ax_1_15, ax_2_15)) = plt.subplots(3, 3, sharex=True, sharey=True, figsize = (16,12))
fig.suptitle('Hedging actions in a Sample Run using Heston Model', fontsize = 20)

sns.lineplot(data=pd.melt(pd.merge(run_trpo_0_90_H,run_delta_0_90_H,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_0_90).set(title="Cost = 0.25%, Frequency = 1 day")
sns.lineplot(data=pd.melt(pd.merge(run_trpo_0_30_H,run_delta_0_30_H,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_0_30).set(title="Cost = 0.25%, Frequency = 3 day")
sns.lineplot(data=pd.melt(pd.merge(run_trpo_0_15_H,run_delta_0_15_H,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_0_15).set(title="Cost = 0.25%, Frequency = 6 day")
sns.lineplot(data=pd.melt(pd.merge(run_trpo_1_90_H,run_delta_1_90_H,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_1_90).set(title="Cost = 0.50%, Frequency = 1 day")
sns.lineplot(data=pd.melt(pd.merge(run_trpo_1_30_H,run_delta_1_30_H,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_1_30).set(title="Cost = 0.50%, Frequency = 3 day")
sns.lineplot(data=pd.melt(pd.merge(run_trpo_1_15_H,run_delta_1_15_H,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_1_15).set(title="Cost = 0.50%, Frequency = 6 day")
sns.lineplot(data=pd.melt(pd.merge(run_trpo_2_90_H,run_delta_2_90_H,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_2_90).set(title="Cost = 0.75%, Frequency = 1 day")
sns.lineplot(data=pd.melt(pd.merge(run_trpo_2_30_H,run_delta_2_30_H,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_2_30).set(title="Cost = 0.75%, Frequency = 3 day")
sns.lineplot(data=pd.melt(pd.merge(run_trpo_2_15_H,run_delta_2_15_H,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_2_15).set(title="Cost = 0.75%, Frequency = 6 day")
# Out:
# [Text(0.5, 1.0, 'Cost = 0.75%, Frequency = 6 day')]

# %% [markdown]
# ### Plot Sample Hedging Actions for Delta vs TRPO agent

# %%
plt.figure(figsize=(8,5))
plt.plot(run_delta_1_30_H['time'], run_delta_1_30_H['price'], 'r', label="Underlying price") # plotting t, a separately 
plt.plot(run_delta_1_30_H['time'], run_delta_1_30_H['action'], 'b:', label="Delta agent") # plotting t, b separately 
plt.plot(run_trpo_1_30_H['time'], run_trpo_1_30_H['action'], 'g:', label="RL agent") # plotting t, c separately 
plt.legend(loc="lower right")
plt.xlabel("Time")
plt.title("Hedging Actions for Underlying Prices", fontsize=20)
plt.show()

# %% [markdown]
# ### Load test results for Delta agent

# %%
test_delta_0_90_H = pd.read_csv("./HestonModel/models/DELTA_25_90/test_results.csv")
test_delta_0_30_H = pd.read_csv("./HestonModel/models/DELTA_25_30/test_results.csv")
test_delta_0_15_H = pd.read_csv("./HestonModel/models/DELTA_25_15/test_results.csv")
test_delta_1_90_H = pd.read_csv("./HestonModel/models/DELTA_50_90/test_results.csv")
test_delta_1_30_H = pd.read_csv("./HestonModel/models/DELTA_50_30/test_results.csv")
test_delta_1_15_H = pd.read_csv("./HestonModel/models/DELTA_50_15/test_results.csv")
test_delta_2_90_H = pd.read_csv("./HestonModel/models/DELTA_75_90/test_results.csv")
test_delta_2_30_H = pd.read_csv("./HestonModel/models/DELTA_75_30/test_results.csv")
test_delta_2_15_H = pd.read_csv("./HestonModel/models/DELTA_75_15/test_results.csv")
test_delta_3_90_H = pd.read_csv("./HestonModel/models/DELTA_100_90/test_results.csv")
test_delta_3_30_H = pd.read_csv("./HestonModel/models/DELTA_100_30/test_results.csv")
test_delta_3_15_H = pd.read_csv("./HestonModel/models/DELTA_100_15/test_results.csv")
test_delta_0_90_H.head()
# Out:
#         pnl      stats      cost
# 0 -1.231584 -44.060183  0.007204
# 1 -1.095840 -40.189688  0.009453
# 2  0.000612 -20.559490  0.008756
# 3 -1.300022 -38.356665  0.007807
# 4 -1.264282 -39.587408  0.009856

# %% [markdown]
# ### Load test results for TRPO agent

# %%
test_trpo_0_90_H = pd.read_csv("./HestonModel/models/TRPO_25_90/test_results.csv")
test_trpo_0_30_H = pd.read_csv("./HestonModel/models/TRPO_25_30/test_results.csv")
test_trpo_0_15_H = pd.read_csv("./HestonModel/models/TRPO_25_15/test_results.csv")
test_trpo_1_90_H = pd.read_csv("./HestonModel/models/TRPO_50_90/test_results.csv")
test_trpo_1_30_H = pd.read_csv("./HestonModel/models/TRPO_50_30/test_results.csv")
test_trpo_1_15_H = pd.read_csv("./HestonModel/models/TRPO_50_15/test_results.csv")
test_trpo_2_90_H = pd.read_csv("./HestonModel/models/TRPO_75_90/test_results.csv")
test_trpo_2_30_H = pd.read_csv("./HestonModel/models/TRPO_75_30/test_results.csv")
test_trpo_2_15_H = pd.read_csv("./HestonModel/models/TRPO_75_15/test_results.csv")
test_trpo_3_90_H = pd.read_csv("./HestonModel/models/TRPO_100_90/test_results.csv")
test_trpo_3_30_H = pd.read_csv("./HestonModel/models/TRPO_100_30/test_results.csv")
test_trpo_3_15_H = pd.read_csv("./HestonModel/models/TRPO_100_15/test_results.csv")
test_trpo_0_90_H.head()
# Out:
#         pnl      stats      cost
# 0 -1.217348 -45.319748  0.006756
# 1 -1.105601 -36.661959  0.010271
# 2 -0.173710 -25.710726  0.007989
# 3 -1.285340 -38.248604  0.007473
# 4 -1.266502 -39.599098  0.010080

# %% [markdown]
# ### Plot P&L Distribution for Delta vs TRPO agent

# %%
fig, ((ax_1_90, ax_2_90, ax_3_90), 
      (ax_1_30, ax_2_30, ax_3_30),
      (ax_1_15, ax_2_15, ax_3_15)) = plt.subplots(3, 3, sharex=True, sharey='row', figsize = (16,12))
fig.suptitle('Kernel Density Estimates of the t-statistic of Total P&L under Heston', fontsize=20)

# sns.kdeplot(data=pd.melt(pd.concat([test_trpo_0_90_H['stats'],test_delta_0_90_H['stats']], 
#                                              axis=1, keys=['TRPO','DELTA']), 
#                                var_name="agent",
#                                value_name="t-test"), 
#                   x="t-test", hue="agent", ax=ax_0_90).set(title="Cost = 0.25%, Frequency = 1 day")
# sns.kdeplot(data=pd.melt(pd.concat([test_trpo_0_30_H['stats'],test_delta_0_30_H['stats']], 
#                                              axis=1, keys=['TRPO','DELTA']), 
#                                var_name="agent",
#                                value_name="t-test"), 
#                   x="t-test", hue="agent", ax=ax_0_30).set(title="Cost = 0.25%, Frequency = 3 day")
# sns.kdeplot(data=pd.melt(pd.concat([test_trpo_0_15_H['stats'],test_delta_0_15_H['stats']], 
#                                              axis=1, keys=['TRPO','DELTA']), 
#                                var_name="agent",
#                                value_name="t-test"), 
#                   x="t-test", hue="agent", ax=ax_0_15).set(title="Cost = 0.25%, Frequency = 6 day")

sns.kdeplot(data=pd.melt(pd.concat([test_trpo_1_90_H['stats'],test_delta_1_90_H['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_1_90).set(title="Cost = 0.50%, Frequency = 1 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_1_30_H['stats'],test_delta_1_30_H['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_1_30).set(title="Cost = 0.50%, Frequency = 3 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_1_15_H['stats'],test_delta_1_15_H['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_1_15).set(title="Cost = 0.50%, Frequency = 6 day")

sns.kdeplot(data=pd.melt(pd.concat([test_trpo_2_90_H['stats'],test_delta_2_90_H['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_2_90).set(title="Cost = 0.75%, Frequency = 1 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_2_30_H['stats'],test_delta_2_30_H['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_2_30).set(title="Cost = 0.75%, Frequency = 3 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_2_15_H['stats'],test_delta_2_15_H['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_2_15).set(title="Cost = 0.75%, Frequency = 6 day")

sns.kdeplot(data=pd.melt(pd.concat([test_trpo_3_90_H['stats'],test_delta_3_90_H['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_3_90).set(title="Cost = 1.00%, Frequency = 1 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_3_30_H['stats'],test_delta_3_30_H['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_3_30).set(title="Cost = 1.00%, Frequency = 3 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_3_15_H['stats'],test_delta_3_15_H['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_3_15).set(title="Cost = 1.00%, Frequency = 6 day")
# Out:
# [Text(0.5, 1.0, 'Cost = 1.00%, Frequency = 6 day')]

# %% [markdown]
# ### Plot Sample P&L Distribution for Delta vs TRPO agent

# %%
plt.figure(figsize=(10,7))
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_2_90_H['stats'],test_delta_2_90_H['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent").set(title="PnL distribution (Cost = 0.50%, Frequency = 3 day)")
# Out:
# [Text(0.5, 1.0, 'PnL distribution (Cost = 0.50%, Frequency = 3 day)')]

# %% [markdown]
# ### Risk Data Results

# %%
riskdata_H = pd.DataFrame(
    {"Frequency": [90,90,90,30,30,30,15,15,15],
     "Cost": [0.25, 0.50, 0.75]*3,
    "Delta VaR": [np.percentile(test_delta_0_90_H['pnl'], 5),
                        np.percentile(test_delta_1_90_H['pnl'], 5),
                        np.percentile(test_delta_2_90_H['pnl'], 5),
                        np.percentile(test_delta_0_30_H['pnl'], 5),
                        np.percentile(test_delta_1_30_H['pnl'], 5),
                        np.percentile(test_delta_2_30_H['pnl'], 5),
                        np.percentile(test_delta_0_15_H['pnl'], 5),
                        np.percentile(test_delta_1_15_H['pnl'], 5),
                        np.percentile(test_delta_2_15_H['pnl'], 5)],
    "Delta CVaR": [np.mean(test_delta_0_90_H['pnl'].loc[lambda s: s < np.percentile(test_delta_0_90_H['pnl'], 5)]),
                        np.mean(test_delta_1_90_H['pnl'].loc[lambda s: s < np.percentile(test_delta_1_90_H['pnl'], 5)]),
                        np.mean(test_delta_2_90_H['pnl'].loc[lambda s: s < np.percentile(test_delta_2_90_H['pnl'], 5)]),
                        np.mean(test_delta_0_30_H['pnl'].loc[lambda s: s < np.percentile(test_delta_0_30_H['pnl'], 5)]),
                        np.mean(test_delta_1_30_H['pnl'].loc[lambda s: s < np.percentile(test_delta_1_30_H['pnl'], 5)]),
                        np.mean(test_delta_2_30_H['pnl'].loc[lambda s: s < np.percentile(test_delta_2_30_H['pnl'], 5)]),
                        np.mean(test_delta_0_15_H['pnl'].loc[lambda s: s < np.percentile(test_delta_0_15_H['pnl'], 5)]),
                        np.mean(test_delta_1_15_H['pnl'].loc[lambda s: s < np.percentile(test_delta_1_15_H['pnl'], 5)]),
                        np.mean(test_delta_2_15_H['pnl'].loc[lambda s: s < np.percentile(test_delta_2_15_H['pnl'], 5)])],
    "TRPO VaR": [np.percentile(test_trpo_0_90_H['pnl'], 5),
                        np.percentile(test_trpo_1_90_H['pnl'], 5),
                        np.percentile(test_trpo_2_90_H['pnl'], 5),
                        np.percentile(test_trpo_0_30_H['pnl'], 5),
                        np.percentile(test_trpo_1_30_H['pnl'], 5),
                        np.percentile(test_trpo_2_30_H['pnl'], 5),
                        np.percentile(test_trpo_0_15_H['pnl'], 5),
                        np.percentile(test_trpo_1_15_H['pnl'], 5),
                        np.percentile(test_trpo_2_15_H['pnl'], 5)],
    "TRPO CVaR": [np.mean(test_trpo_0_90_H['pnl'].loc[lambda s: s < np.percentile(test_trpo_0_90_H['pnl'], 5)]),
                        np.mean(test_trpo_1_90_H['pnl'].loc[lambda s: s < np.percentile(test_trpo_1_90_H['pnl'], 5)]),
                        np.mean(test_trpo_2_90_H['pnl'].loc[lambda s: s < np.percentile(test_trpo_2_90_H['pnl'], 5)]),
                        np.mean(test_trpo_0_30_H['pnl'].loc[lambda s: s < np.percentile(test_trpo_0_30_H['pnl'], 5)]),
                        np.mean(test_trpo_1_30_H['pnl'].loc[lambda s: s < np.percentile(test_trpo_1_30_H['pnl'], 5)]),
                        np.mean(test_trpo_2_30_H['pnl'].loc[lambda s: s < np.percentile(test_trpo_2_30_H['pnl'], 5)]),
                        np.mean(test_trpo_0_15_H['pnl'].loc[lambda s: s < np.percentile(test_trpo_0_15_H['pnl'], 5)]),
                        np.mean(test_trpo_1_15_H['pnl'].loc[lambda s: s < np.percentile(test_trpo_1_15_H['pnl'], 5)]),
                        np.mean(test_trpo_2_15_H['pnl'].loc[lambda s: s < np.percentile(test_trpo_2_15_H['pnl'], 5)])]
    }
)
riskdata_H["VaR Improvement"] = 100*(riskdata_H["Delta VaR"]-riskdata_H["TRPO VaR"])/riskdata_H["Delta VaR"]
riskdata_H["CVaR Improvement"] = 100*(riskdata_H["Delta CVaR"]-riskdata_H["TRPO CVaR"])/riskdata_H["Delta CVaR"]
# print(riskdata_H.to_string(index=False))
riskdata_H.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_287bb">
#   <thead>
#     <tr>
#       <th id="T_287bb_level0_col0" class="col_heading level0 col0" >Frequency</th>
#       <th id="T_287bb_level0_col1" class="col_heading level0 col1" >Cost</th>
#       <th id="T_287bb_level0_col2" class="col_heading level0 col2" >Delta VaR</th>
#       <th id="T_287bb_level0_col3" class="col_heading level0 col3" >Delta CVaR</th>
#       <th id="T_287bb_level0_col4" class="col_heading level0 col4" >TRPO VaR</th>
#       <th id="T_287bb_level0_col5" class="col_heading level0 col5" >TRPO CVaR</th>
#       <th id="T_287bb_level0_col6" class="col_heading level0 col6" >VaR Improvement</th>
#       <th id="T_287bb_level0_col7" class="col_heading level0 col7" >CVaR Improvement</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_287bb_row0_col0" class="data row0 col0" >90</td>
#       <td id="T_287bb_row0_col1" class="data row0 col1" >0.250000</td>
# ...

# %% [markdown]
# ### Plot Cost Distribution for Delta vs TRPO agent

# %%
fig, ((ax_0_90, ax_1_90, ax_2_90), 
      (ax_0_30, ax_1_30, ax_2_30),
      (ax_0_15, ax_1_15, ax_2_15)) = plt.subplots(3, 3, sharex=True, sharey='row', figsize = (16,12))
fig.suptitle('Kernel Density Estimates of the Total Cost under Heston', fontsize=20)

sns.kdeplot(data=pd.melt(pd.concat([test_trpo_0_90_H['cost'],test_delta_0_90_H['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_0_90).set(title="Cost = 0.25%, Frequency = 1 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_0_30_H['cost'],test_delta_0_30_H['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_0_30).set(title="Cost = 0.25%, Frequency = 3 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_0_15_H['cost'],test_delta_0_15_H['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_0_15).set(title="Cost = 0.25%, Frequency = 6 day")

sns.kdeplot(data=pd.melt(pd.concat([test_trpo_1_90_H['cost'],test_delta_1_90_H['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_1_90).set(title="Cost = 0.50%, Frequency = 1 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_1_30_H['cost'],test_delta_1_30_H['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_1_30).set(title="Cost = 0.50%, Frequency = 3 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_1_15_H['cost'],test_delta_1_15_H['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_1_15).set(title="Cost = 0.50%, Frequency = 6 day")

sns.kdeplot(data=pd.melt(pd.concat([test_trpo_2_90_H['cost'],test_delta_2_90_H['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_2_90).set(title="Cost = 0.75%, Frequency = 1 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_2_30_H['cost'],test_delta_2_30_H['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_2_30).set(title="Cost = 0.75%, Frequency = 3 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_2_15_H['cost'],test_delta_2_15_H['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_2_15).set(title="Cost = 0.75%, Frequency = 6 day")

# sns.kdeplot(data=pd.melt(pd.concat([test_trpo_3_90_H['cost'],test_delta_3_90_H['cost']], 
#                                              axis=1, keys=['TRPO','DELTA']), 
#                                var_name="agent",
#                                value_name="cost"), 
#                   x="cost", hue="agent", ax=ax_3_90).set(title="Cost = 1.00%, Frequency = 1 day")
# sns.kdeplot(data=pd.melt(pd.concat([test_trpo_3_30_H['cost'],test_delta_3_30_H['cost']], 
#                                              axis=1, keys=['TRPO','DELTA']), 
#                                var_name="agent",
#                                value_name="cost"), 
#                   x="cost", hue="agent", ax=ax_3_30).set(title="Cost = 1.00%, Frequency = 3 day")
# sns.kdeplot(data=pd.melt(pd.concat([test_trpo_3_15_H['cost'],test_delta_3_15_H['cost']], 
#                                              axis=1, keys=['TRPO','DELTA']), 
#                                var_name="agent",
#                                value_name="cost"), 
#                   x="cost", hue="agent", ax=ax_3_15).set(title="Cost = 1.00%, Frequency = 6 day")
# Out:
# [Text(0.5, 1.0, 'Cost = 0.75%, Frequency = 6 day')]

# %% [markdown]
# ### Plot Sample Cost Distribution for Delta vs TRPO agent

# %%
plt.figure(figsize=(10,7))
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_2_90_H['cost'],test_delta_2_90_H['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent").set(title="Cost = 0.75%, Frequency = 1 day")
# Out:
# [Text(0.5, 1.0, 'Cost = 0.75%, Frequency = 1 day')]

# %% [markdown]
# ### Cost Data Results

# %%
costdata_H = pd.DataFrame(
    {"Frequency": [90,90,90,30,30,30,15,15,15],
     "Cost": [0.25, 0.50, 0.75]*3,
    "Delta Mean Cost": [np.mean(test_delta_0_90_H['cost']),
                        np.mean(test_delta_1_90_H['cost']),
                        np.mean(test_delta_2_90_H['cost']),
                        np.mean(test_delta_0_30_H['cost']),
                        np.mean(test_delta_1_30_H['cost']),
                        np.mean(test_delta_2_30_H['cost']),
                        np.mean(test_delta_0_15_H['cost']),
                        np.mean(test_delta_1_15_H['cost']),
                        np.mean(test_delta_2_15_H['cost'])],
    "Delta SD Cost": [np.std(test_delta_0_90_H['cost']),
                        np.std(test_delta_1_90_H['cost']),
                        np.std(test_delta_2_90_H['cost']),
                        np.std(test_delta_0_30_H['cost']),
                        np.std(test_delta_1_30_H['cost']),
                        np.std(test_delta_2_30_H['cost']),
                        np.std(test_delta_0_15_H['cost']),
                        np.std(test_delta_1_15_H['cost']),
                        np.std(test_delta_2_15_H['cost'])],
    "TRPO Mean Cost": [np.mean(test_trpo_0_90_H['cost']),
                        np.mean(test_trpo_1_90_H['cost']),
                        np.mean(test_trpo_2_90_H['cost']),
                        np.mean(test_trpo_0_30_H['cost']),
                        np.mean(test_trpo_1_30_H['cost']),
                        np.mean(test_trpo_2_30_H['cost']),
                        np.mean(test_trpo_0_15_H['cost']),
                        np.mean(test_trpo_1_15_H['cost']),
                        np.mean(test_trpo_2_15_H['cost'])],
    "TRPO SD Cost": [np.std(test_trpo_0_90_H['cost']),
                        np.std(test_trpo_1_90_H['cost']),
                        np.std(test_trpo_2_90_H['cost']),
                        np.std(test_trpo_0_30_H['cost']),
                        np.std(test_trpo_1_30_H['cost']),
                        np.std(test_trpo_2_30_H['cost']),
                        np.std(test_trpo_0_15_H['cost']),
                        np.std(test_trpo_1_15_H['cost']),
                        np.std(test_trpo_2_15_H['cost'])]}
)
costdata_H["Mean Cost Improvement (%)"] = 100*(costdata_H["Delta Mean Cost"]-costdata_H["TRPO Mean Cost"])/costdata_H["Delta Mean Cost"]
costdata_H["SD Cost Improvement (%)"] = 100*(costdata_H["Delta SD Cost"]-costdata_H["TRPO SD Cost"])/costdata_H["Delta SD Cost"]
costdata_H.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_bb9bf">
#   <thead>
#     <tr>
#       <th id="T_bb9bf_level0_col0" class="col_heading level0 col0" >Frequency</th>
#       <th id="T_bb9bf_level0_col1" class="col_heading level0 col1" >Cost</th>
#       <th id="T_bb9bf_level0_col2" class="col_heading level0 col2" >Delta Mean Cost</th>
#       <th id="T_bb9bf_level0_col3" class="col_heading level0 col3" >Delta SD Cost</th>
#       <th id="T_bb9bf_level0_col4" class="col_heading level0 col4" >TRPO Mean Cost</th>
#       <th id="T_bb9bf_level0_col5" class="col_heading level0 col5" >TRPO SD Cost</th>
#       <th id="T_bb9bf_level0_col6" class="col_heading level0 col6" >Mean Cost Improvement (%)</th>
#       <th id="T_bb9bf_level0_col7" class="col_heading level0 col7" >SD Cost Improvement (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bb9bf_row0_col0" class="data row0 col0" >90</td>
#       <td id="T_bb9bf_row0_col1" class="data row0 col1" >0.250000</td>
# ...

# %% [markdown]
# ## Geometric Brownian Motion (GBM) Model

# %% [markdown]
# ### Load TRPO Learning Curves

# %%
lc_trpo_0_90_B = pd.read_csv("./BlackScholesModel/models/TRPO_25_90/learning_curve.csv")
lc_trpo_0_30_B = pd.read_csv("./BlackScholesModel/models/TRPO_25_30/learning_curve.csv")
lc_trpo_0_15_B = pd.read_csv("./BlackScholesModel/models/TRPO_25_15/learning_curve.csv")
lc_trpo_1_90_B = pd.read_csv("./BlackScholesModel/models/TRPO_50_90/learning_curve.csv")
lc_trpo_1_30_B = pd.read_csv("./BlackScholesModel/models/TRPO_50_30/learning_curve.csv")
lc_trpo_1_15_B = pd.read_csv("./BlackScholesModel/models/TRPO_50_15/learning_curve.csv")
lc_trpo_2_90_B = pd.read_csv("./BlackScholesModel/models/TRPO_75_90/learning_curve.csv")
lc_trpo_2_30_B = pd.read_csv("./BlackScholesModel/models/TRPO_75_30/learning_curve.csv")
lc_trpo_2_15_B = pd.read_csv("./BlackScholesModel/models/TRPO_75_15/learning_curve.csv")
lc_trpo_3_90_B = pd.read_csv("./BlackScholesModel/models/TRPO_100_90/learning_curve.csv")
lc_trpo_3_30_B = pd.read_csv("./BlackScholesModel/models/TRPO_100_30/learning_curve.csv")
lc_trpo_3_15_B = pd.read_csv("./BlackScholesModel/models/TRPO_100_15/learning_curve.csv")
lc_trpo_0_90_B.head()
# Out:
#    Number of Episodes     Rewards
# 0                4500 -136.358986
# 1                4590 -134.194858
# 2                4680 -131.606283
# 3                4770 -131.521309
# 4                4860 -133.242267

# %% [markdown]
# ### Plot TRPO Learning Curves

# %%
fig, ((ax_1_90, ax_2_90, ax_3_90), 
      (ax_1_30, ax_2_30, ax_3_30),
      (ax_1_15, ax_2_15, ax_3_15)) = plt.subplots(3, 3, sharex=True, sharey=True, figsize = (16,10))

# sns.lineplot(data=lc_trpo_0_90_B, x="Number of Episodes", y="Rewards", ax=ax_0_90)
# sns.lineplot(data=lc_trpo_0_30_B, x="Number of Episodes", y="Rewards", ax=ax_0_30)
# sns.lineplot(data=lc_trpo_0_15_B, x="Number of Episodes", y="Rewards", ax=ax_0_15)
sns.lineplot(data=lc_trpo_1_90_B, x="Number of Episodes", y="Rewards", ax=ax_1_90)
sns.lineplot(data=lc_trpo_1_30_B, x="Number of Episodes", y="Rewards", ax=ax_1_30)
sns.lineplot(data=lc_trpo_1_15_B, x="Number of Episodes", y="Rewards", ax=ax_1_15)
sns.lineplot(data=lc_trpo_2_90_B, x="Number of Episodes", y="Rewards", ax=ax_2_90)
sns.lineplot(data=lc_trpo_2_30_B, x="Number of Episodes", y="Rewards", ax=ax_2_30)
sns.lineplot(data=lc_trpo_2_15_B, x="Number of Episodes", y="Rewards", ax=ax_2_15)
sns.lineplot(data=lc_trpo_3_90_B, x="Number of Episodes", y="Rewards", ax=ax_3_90)
sns.lineplot(data=lc_trpo_3_30_B, x="Number of Episodes", y="Rewards", ax=ax_3_30)
sns.lineplot(data=lc_trpo_3_15_B, x="Number of Episodes", y="Rewards", ax=ax_3_15)
# Out:
# <AxesSubplot:xlabel='Number of Episodes', ylabel='Rewards'>

# %% [markdown]
# ### Plot Sample TRPO Learning Curve

# %%
title='Learning Curve'
fig = plt.figure(title)
plt.figure(figsize=(8,5))
plt.plot(lc_trpo_1_30_B["Number of Episodes"], lc_trpo_1_30_B["Rewards"])
plt.xlabel('Number of Episodes')
plt.ylabel('Rewards')
plt.title(title + " Smoothed", fontsize=20)
plt.show()

# %% [markdown]
# ### Load Test Path for Delta agent

# %%
run_delta_0_90_B = pd.read_csv("./BlackScholesModel/models/DELTA_25_90/test_run.csv")
run_delta_0_30_B = pd.read_csv("./BlackScholesModel/models/DELTA_25_30/test_run.csv")
run_delta_0_15_B = pd.read_csv("./BlackScholesModel/models/DELTA_25_15/test_run.csv")
run_delta_1_90_B = pd.read_csv("./BlackScholesModel/models/DELTA_50_90/test_run.csv")
run_delta_1_30_B = pd.read_csv("./BlackScholesModel/models/DELTA_50_30/test_run.csv")
run_delta_1_15_B = pd.read_csv("./BlackScholesModel/models/DELTA_50_15/test_run.csv")
run_delta_2_90_B = pd.read_csv("./BlackScholesModel/models/DELTA_75_90/test_run.csv")
run_delta_2_30_B = pd.read_csv("./BlackScholesModel/models/DELTA_75_30/test_run.csv")
run_delta_2_15_B = pd.read_csv("./BlackScholesModel/models/DELTA_75_15/test_run.csv")
run_delta_3_90_B = pd.read_csv("./BlackScholesModel/models/DELTA_100_90/test_run.csv")
run_delta_3_30_B = pd.read_csv("./BlackScholesModel/models/DELTA_100_30/test_run.csv")
run_delta_3_15_B = pd.read_csv("./BlackScholesModel/models/DELTA_100_15/test_run.csv")
run_delta_0_90_B.head()
# Out:
#        time     price    action
# 0  0.000000  1.000000  0.562816
# 1  0.002809  0.983650  0.520890
# 2  0.005618  0.977639  0.504668
# 3  0.008427  0.998851  0.558853
# 4  0.011236  1.002085  0.566723

# %% [markdown]
# ### Load Test Path for TRPO agent

# %%
run_trpo_0_90_B = pd.read_csv("./BlackScholesModel/models/TRPO_25_90/test_run.csv")
run_trpo_0_30_B = pd.read_csv("./BlackScholesModel/models/TRPO_25_30/test_run.csv")
run_trpo_0_15_B = pd.read_csv("./BlackScholesModel/models/TRPO_25_15/test_run.csv")
run_trpo_1_90_B = pd.read_csv("./BlackScholesModel/models/TRPO_50_90/test_run.csv")
run_trpo_1_30_B = pd.read_csv("./BlackScholesModel/models/TRPO_50_30/test_run.csv")
run_trpo_1_15_B = pd.read_csv("./BlackScholesModel/models/TRPO_50_15/test_run.csv")
run_trpo_2_90_B = pd.read_csv("./BlackScholesModel/models/TRPO_75_90/test_run.csv")
run_trpo_2_30_B = pd.read_csv("./BlackScholesModel/models/TRPO_75_30/test_run.csv")
run_trpo_2_15_B = pd.read_csv("./BlackScholesModel/models/TRPO_75_15/test_run.csv")
run_trpo_3_90_B = pd.read_csv("./BlackScholesModel/models/TRPO_100_90/test_run.csv")
run_trpo_3_30_B = pd.read_csv("./BlackScholesModel/models/TRPO_100_30/test_run.csv")
run_trpo_3_15_B = pd.read_csv("./BlackScholesModel/models/TRPO_100_15/test_run.csv")
run_trpo_0_90_B.head()
# Out:
#        time     price    action
# 0  0.000000  1.000000  0.409513
# 1  0.002809  0.983650  0.497310
# 2  0.005618  0.977639  0.495930
# 3  0.008427  0.998851  0.546167
# 4  0.011236  1.002085  0.561931

# %% [markdown]
# ### Plot Hedging Action for Delta vs TRPO

# %%
fig, ((ax_0_90, ax_1_90, ax_2_90), 
      (ax_0_30, ax_1_30, ax_2_30),
      (ax_0_15, ax_1_15, ax_2_15)) = plt.subplots(3, 3, sharex=True, sharey=True, figsize = (16,12))
fig.suptitle('Hedging actions in a Sample Run using GBM', fontsize=20)

sns.lineplot(data=pd.melt(pd.merge(run_trpo_0_90_B,run_delta_0_90_B,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_0_90).set(title="Cost = 0.25%, Frequency = 1 day")
sns.lineplot(data=pd.melt(pd.merge(run_trpo_0_30_B,run_delta_0_30_B,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_0_30).set(title="Cost = 0.25%, Frequency = 3 day")
sns.lineplot(data=pd.melt(pd.merge(run_trpo_0_15_B,run_delta_0_15_B,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_0_15).set(title="Cost = 0.25%, Frequency = 6 day")

sns.lineplot(data=pd.melt(pd.merge(run_trpo_1_90_B,run_delta_1_90_B,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_1_90).set(title="Cost = 0.50%, Frequency = 1 day")
sns.lineplot(data=pd.melt(pd.merge(run_trpo_1_30_B,run_delta_1_30_B,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_1_30).set(title="Cost = 0.50%, Frequency = 3 day")
sns.lineplot(data=pd.melt(pd.merge(run_trpo_1_15_B,run_delta_1_15_B,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_1_15).set(title="Cost = 0.50%, Frequency = 6 day")

sns.lineplot(data=pd.melt(pd.merge(run_trpo_2_90_B,run_delta_2_90_B,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_2_90).set(title="Cost = 0.75%, Frequency = 1 day")
sns.lineplot(data=pd.melt(pd.merge(run_trpo_2_30_B,run_delta_2_30_B,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_2_30).set(title="Cost = 0.75%, Frequency = 3 day")
sns.lineplot(data=pd.melt(pd.merge(run_trpo_2_15_B,run_delta_2_15_B,how='inner',on=['time','price'])
                          .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
                         id_vars=['Time'],
                         value_vars=['Underlying Price','RL Agent','Delta Agent']),
             x='Time',y='value',hue='variable',ax=ax_2_15).set(title="Cost = 0.75%, Frequency = 6 day")

# sns.lineplot(data=pd.melt(pd.merge(run_trpo_3_90_B,run_delta_3_90_B,how='inner',on=['time','price'])
#                           .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
#                          id_vars=['Time'],
#                          value_vars=['Underlying Price','RL Agent','Delta Agent']),
#              x='Time',y='value',hue='variable',ax=ax_3_90).set(title="Cost = 1.00%, Frequency = 1 day")
# sns.lineplot(data=pd.melt(pd.merge(run_trpo_3_30_B,run_delta_3_30_B,how='inner',on=['time','price'])
#                           .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
#                          id_vars=['Time'],
#                          value_vars=['Underlying Price','RL Agent','Delta Agent']),
#              x='Time',y='value',hue='variable',ax=ax_3_30).set(title="Cost = 1.00%, Frequency = 3 day")
# sns.lineplot(data=pd.melt(pd.merge(run_trpo_3_15_B,run_delta_3_15_B,how='inner',on=['time','price'])
#                           .rename(columns={'time':'Time', 'price': 'Underlying Price','action_x':'RL Agent','action_y':'Delta Agent'}),
#                          id_vars=['Time'],
#                          value_vars=['Underlying Price','RL Agent','Delta Agent']),
#              x='Time',y='value',hue='variable',ax=ax_3_15).set(title="Cost = 1.00%, Frequency = 6 day")
# Out:
# [Text(0.5, 1.0, 'Cost = 0.75%, Frequency = 6 day')]

# %% [markdown]
# ### Plot Sample Hedging Action for Delta vs TRPO

# %%
plt.figure(figsize=(8,5))
plt.plot(run_delta_1_30_B['time'], run_delta_1_30_B['price'], 'r', label="Underlying price") # plotting t, a separately 
plt.plot(run_delta_1_30_B['time'], run_delta_1_30_B['action'], 'b:', label="Delta agent") # plotting t, b separately 
plt.plot(run_trpo_1_30_B['time'], run_trpo_1_30_B['action'], 'g:', label="RL agent") # plotting t, c separately 
plt.legend(loc="lower right")
plt.xlabel("Time")
plt.title("Hedging Actions for Underlying Prices", fontsize=20)
plt.show()

# %% [markdown]
# ### Load test data for Delta agent

# %%
test_delta_0_90_B = pd.read_csv("./BlackScholesModel/models/DELTA_25_90/test_results.csv")
test_delta_0_30_B = pd.read_csv("./BlackScholesModel/models/DELTA_25_30/test_results.csv")
test_delta_0_15_B = pd.read_csv("./BlackScholesModel/models/DELTA_25_15/test_results.csv")
test_delta_1_90_B = pd.read_csv("./BlackScholesModel/models/DELTA_50_90/test_results.csv")
test_delta_1_30_B = pd.read_csv("./BlackScholesModel/models/DELTA_50_30/test_results.csv")
test_delta_1_15_B = pd.read_csv("./BlackScholesModel/models/DELTA_50_15/test_results.csv")
test_delta_2_90_B = pd.read_csv("./BlackScholesModel/models/DELTA_75_90/test_results.csv")
test_delta_2_30_B = pd.read_csv("./BlackScholesModel/models/DELTA_75_30/test_results.csv")
test_delta_2_15_B = pd.read_csv("./BlackScholesModel/models/DELTA_75_15/test_results.csv")
test_delta_3_90_B = pd.read_csv("./BlackScholesModel/models/DELTA_100_90/test_results.csv")
test_delta_3_30_B = pd.read_csv("./BlackScholesModel/models/DELTA_100_30/test_results.csv")
test_delta_3_15_B = pd.read_csv("./BlackScholesModel/models/DELTA_100_15/test_results.csv")
test_delta_0_90_B.head()
# Out:
#         pnl      stats      cost
# 0 -1.112409 -38.247172  0.010444
# 1 -1.276124 -37.202644  0.009140
# 2 -0.030854 -24.735302  0.013843
# 3 -0.210085 -15.682188  0.012102
# 4 -0.010552 -12.853319  0.007726

# %% [markdown]
# ### Load test data for TRPO agent

# %%
test_trpo_0_90_B = pd.read_csv("./BlackScholesModel/models/TRPO_25_90/test_results.csv")
test_trpo_0_30_B = pd.read_csv("./BlackScholesModel/models/TRPO_25_30/test_results.csv")
test_trpo_0_15_B = pd.read_csv("./BlackScholesModel/models/TRPO_25_15/test_results.csv")
test_trpo_1_90_B = pd.read_csv("./BlackScholesModel/models/TRPO_50_90/test_results.csv")
test_trpo_1_30_B = pd.read_csv("./BlackScholesModel/models/TRPO_50_30/test_results.csv")
test_trpo_1_15_B = pd.read_csv("./BlackScholesModel/models/TRPO_50_15/test_results.csv")
test_trpo_2_90_B = pd.read_csv("./BlackScholesModel/models/TRPO_75_90/test_results.csv")
test_trpo_2_30_B = pd.read_csv("./BlackScholesModel/models/TRPO_75_30/test_results.csv")
test_trpo_2_15_B = pd.read_csv("./BlackScholesModel/models/TRPO_75_15/test_results.csv")
test_trpo_3_90_B = pd.read_csv("./BlackScholesModel/models/TRPO_100_90/test_results.csv")
test_trpo_3_30_B = pd.read_csv("./BlackScholesModel/models/TRPO_100_30/test_results.csv")
test_trpo_3_15_B = pd.read_csv("./BlackScholesModel/models/TRPO_100_15/test_results.csv")
test_trpo_0_90_B.head()
# Out:
#         pnl      stats      cost
# 0 -1.111790 -35.113329  0.009969
# 1 -1.277135 -37.985886  0.009474
# 2 -0.330558 -25.750809  0.011575
# 3 -0.482144 -19.832411  0.008831
# 4  0.050544 -13.951380  0.007672

# %% [markdown]
# ### Plot P&L Distribution for Delta vs TRPO agent

# %%
fig, ((ax_0_90, ax_1_90, ax_2_90), 
      (ax_0_30, ax_1_30, ax_2_30),
      (ax_0_15, ax_1_15, ax_2_15)) = plt.subplots(3, 3, sharex=True, sharey='row', figsize = (16,12))
fig.suptitle('Kernel Density Estimates of the t-statistic of Total P&L under GBM', fontsize=20)

sns.kdeplot(data=pd.melt(pd.concat([test_trpo_0_90_B['stats'],test_delta_0_90_B['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_0_90).set(title="Cost = 0.25%, Frequency = 1 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_0_30_B['stats'],test_delta_0_30_B['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_0_30).set(title="Cost = 0.25%, Frequency = 3 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_0_15_B['stats'],test_delta_0_15_B['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_0_15).set(title="Cost = 0.25%, Frequency = 6 day")

sns.kdeplot(data=pd.melt(pd.concat([test_trpo_1_90_B['stats'],test_delta_1_90_B['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_1_90).set(title="Cost = 0.50%, Frequency = 1 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_1_30_B['stats'],test_delta_1_30_B['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_1_30).set(title="Cost = 0.50%, Frequency = 3 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_1_15_B['stats'],test_delta_1_15_B['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_1_15).set(title="Cost = 0.50%, Frequency = 6 day")

sns.kdeplot(data=pd.melt(pd.concat([test_trpo_2_90_B['stats'],test_delta_2_90_B['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_2_90).set(title="Cost = 0.75%, Frequency = 1 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_2_30_B['stats'],test_delta_2_30_B['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_2_30).set(title="Cost = 0.75%, Frequency = 3 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_2_15_B['stats'],test_delta_2_15_B['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent", ax=ax_2_15).set(title="Cost = 0.75%, Frequency = 6 day")

# sns.kdeplot(data=pd.melt(pd.concat([test_trpo_3_90_B['stats'],test_delta_3_90_B['stats']], 
#                                              axis=1, keys=['TRPO','DELTA']), 
#                                var_name="agent",
#                                value_name="t-test"), 
#                   x="t-test", hue="agent", ax=ax_3_90).set(title="Cost = 1.00%, Frequency = 1 day")
# sns.kdeplot(data=pd.melt(pd.concat([test_trpo_3_30_B['stats'],test_delta_3_30_B['stats']], 
#                                              axis=1, keys=['TRPO','DELTA']), 
#                                var_name="agent",
#                                value_name="t-test"), 
#                   x="t-test", hue="agent", ax=ax_3_30).set(title="Cost = 1.00%, Frequency = 3 day")
# sns.kdeplot(data=pd.melt(pd.concat([test_trpo_3_15_B['stats'],test_delta_3_15_B['stats']], 
#                                              axis=1, keys=['TRPO','DELTA']), 
#                                var_name="agent",
#                                value_name="t-test"), 
#                   x="t-test", hue="agent", ax=ax_3_15).set(title="Cost = 1.00%, Frequency = 6 day")
# Out:
# [Text(0.5, 1.0, 'Cost = 0.75%, Frequency = 6 day')]

# %% [markdown]
# ### Plot Sample P&L Distribution for Delta vs TRPO agent

# %%
plt.figure(figsize=(10,7))
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_2_30_B['stats'],test_delta_2_30_B['stats']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="t-test"), 
                  x="t-test", hue="agent").set(title="PnL distribution (Cost = 0.50%, Frequency = 3 day)")
# Out:
# [Text(0.5, 1.0, 'PnL distribution (Cost = 0.50%, Frequency = 3 day)')]

# %% [markdown]
# ### Risk Data Results

# %%
riskdata_B = pd.DataFrame(
    {"Frequency": [90,90,90,30,30,30,15,15,15],
     "Cost": [0.25, 0.50, 0.75]*3,
    "Delta VaR": [np.percentile(test_delta_0_90_B['pnl'], 5),
                        np.percentile(test_delta_1_90_B['pnl'], 5),
                        np.percentile(test_delta_2_90_B['pnl'], 5),
                        np.percentile(test_delta_0_30_B['pnl'], 5),
                        np.percentile(test_delta_1_30_B['pnl'], 5),
                        np.percentile(test_delta_2_30_B['pnl'], 5),
                        np.percentile(test_delta_0_15_B['pnl'], 5),
                        np.percentile(test_delta_1_15_B['pnl'], 5),
                        np.percentile(test_delta_2_15_B['pnl'], 5)],
    "Delta CVaR": [np.mean(test_delta_0_90_B['pnl'].loc[lambda s: s < np.percentile(test_delta_0_90_B['pnl'], 5)]),
                        np.mean(test_delta_1_90_B['pnl'].loc[lambda s: s < np.percentile(test_delta_1_90_B['pnl'], 5)]),
                        np.mean(test_delta_2_90_B['pnl'].loc[lambda s: s < np.percentile(test_delta_2_90_B['pnl'], 5)]),
                        np.mean(test_delta_0_30_B['pnl'].loc[lambda s: s < np.percentile(test_delta_0_30_B['pnl'], 5)]),
                        np.mean(test_delta_1_30_B['pnl'].loc[lambda s: s < np.percentile(test_delta_1_30_B['pnl'], 5)]),
                        np.mean(test_delta_2_30_B['pnl'].loc[lambda s: s < np.percentile(test_delta_2_30_B['pnl'], 5)]),
                        np.mean(test_delta_0_15_B['pnl'].loc[lambda s: s < np.percentile(test_delta_0_15_B['pnl'], 5)]),
                        np.mean(test_delta_1_15_B['pnl'].loc[lambda s: s < np.percentile(test_delta_1_15_B['pnl'], 5)]),
                        np.mean(test_delta_2_15_B['pnl'].loc[lambda s: s < np.percentile(test_delta_2_15_B['pnl'], 5)])],
    "TRPO VaR": [np.percentile(test_trpo_0_90_B['pnl'], 5),
                        np.percentile(test_trpo_1_90_B['pnl'], 5),
                        np.percentile(test_trpo_2_90_B['pnl'], 5),
                        np.percentile(test_trpo_0_30_B['pnl'], 5),
                        np.percentile(test_trpo_1_30_B['pnl'], 5),
                        np.percentile(test_trpo_2_30_B['pnl'], 5),
                        np.percentile(test_trpo_0_15_B['pnl'], 5),
                        np.percentile(test_trpo_1_15_B['pnl'], 5),
                        np.percentile(test_trpo_2_15_B['pnl'], 5)],
    "TRPO CVaR": [np.mean(test_trpo_0_90_B['pnl'].loc[lambda s: s < np.percentile(test_trpo_0_90_B['pnl'], 5)]),
                        np.mean(test_trpo_1_90_B['pnl'].loc[lambda s: s < np.percentile(test_trpo_1_90_B['pnl'], 5)]),
                        np.mean(test_trpo_2_90_B['pnl'].loc[lambda s: s < np.percentile(test_trpo_2_90_B['pnl'], 5)]),
                        np.mean(test_trpo_0_30_B['pnl'].loc[lambda s: s < np.percentile(test_trpo_0_30_B['pnl'], 5)]),
                        np.mean(test_trpo_1_30_B['pnl'].loc[lambda s: s < np.percentile(test_trpo_1_30_B['pnl'], 5)]),
                        np.mean(test_trpo_2_30_B['pnl'].loc[lambda s: s < np.percentile(test_trpo_2_30_B['pnl'], 5)]),
                        np.mean(test_trpo_0_15_B['pnl'].loc[lambda s: s < np.percentile(test_trpo_0_15_B['pnl'], 5)]),
                        np.mean(test_trpo_1_15_B['pnl'].loc[lambda s: s < np.percentile(test_trpo_1_15_B['pnl'], 5)]),
                        np.mean(test_trpo_2_15_B['pnl'].loc[lambda s: s < np.percentile(test_trpo_2_15_B['pnl'], 5)])]
    }
)
riskdata_B["VaR Improvement (%)"] = 100*(riskdata_B["Delta VaR"]-riskdata_B["TRPO VaR"])/riskdata_B["Delta VaR"]
riskdata_B["CVaR Improvement (%)"] = 100*(riskdata_B["Delta CVaR"]-riskdata_B["TRPO CVaR"])/riskdata_B["Delta CVaR"]
riskdata_B.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e67fd">
#   <thead>
#     <tr>
#       <th id="T_e67fd_level0_col0" class="col_heading level0 col0" >Frequency</th>
#       <th id="T_e67fd_level0_col1" class="col_heading level0 col1" >Cost</th>
#       <th id="T_e67fd_level0_col2" class="col_heading level0 col2" >Delta VaR</th>
#       <th id="T_e67fd_level0_col3" class="col_heading level0 col3" >Delta CVaR</th>
#       <th id="T_e67fd_level0_col4" class="col_heading level0 col4" >TRPO VaR</th>
#       <th id="T_e67fd_level0_col5" class="col_heading level0 col5" >TRPO CVaR</th>
#       <th id="T_e67fd_level0_col6" class="col_heading level0 col6" >VaR Improvement (%)</th>
#       <th id="T_e67fd_level0_col7" class="col_heading level0 col7" >CVaR Improvement (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e67fd_row0_col0" class="data row0 col0" >90</td>
#       <td id="T_e67fd_row0_col1" class="data row0 col1" >0.250000</td>
# ...

# %% [markdown]
# ### Plot Cost Distribution for Delta vs TRPO agent

# %%
fig, ((ax_0_90, ax_1_90, ax_2_90), 
      (ax_0_30, ax_1_30, ax_2_30),
      (ax_0_15, ax_1_15, ax_2_15)) = plt.subplots(3, 3, sharex=True, sharey='row', figsize = (16,12))
fig.suptitle('Kernel Density Estimates of the Total Cost under GBM', fontsize=20)

sns.kdeplot(data=pd.melt(pd.concat([test_trpo_0_90_B['cost'],test_delta_0_90_B['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_0_90).set(title="Cost = 0.25%, Frequency = 1 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_0_30_B['cost'],test_delta_0_30_B['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_0_30).set(title="Cost = 0.25%, Frequency = 3 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_0_15_B['cost'],test_delta_0_15_B['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_0_15).set(title="Cost = 0.25%, Frequency = 6 day")

sns.kdeplot(data=pd.melt(pd.concat([test_trpo_1_90_B['cost'],test_delta_1_90_B['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_1_90).set(title="Cost = 0.50%, Frequency = 1 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_1_30_B['cost'],test_delta_1_30_B['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_1_30).set(title="Cost = 0.50%, Frequency = 3 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_1_15_B['cost'],test_delta_1_15_B['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_1_15).set(title="Cost = 0.50%, Frequency = 6 day")

sns.kdeplot(data=pd.melt(pd.concat([test_trpo_2_90_B['cost'],test_delta_2_90_B['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_2_90).set(title="Cost = 0.75%, Frequency = 1 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_2_30_B['cost'],test_delta_2_30_B['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_2_30).set(title="Cost = 0.75%, Frequency = 3 day")
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_2_15_B['cost'],test_delta_2_15_B['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent", ax=ax_2_15).set(title="Cost = 0.75%, Frequency = 6 day")

# sns.kdeplot(data=pd.melt(pd.concat([test_trpo_3_90_B['cost'],test_delta_3_90_B['cost']], 
#                                              axis=1, keys=['TRPO','DELTA']), 
#                                var_name="agent",
#                                value_name="cost"), 
#                   x="cost", hue="agent", ax=ax_3_90).set(title="Cost = 1.00%, Frequency = 1 day")
# sns.kdeplot(data=pd.melt(pd.concat([test_trpo_3_30_B['cost'],test_delta_3_30_B['cost']], 
#                                              axis=1, keys=['TRPO','DELTA']), 
#                                var_name="agent",
#                                value_name="cost"), 
#                   x="cost", hue="agent", ax=ax_3_30).set(title="Cost = 1.00%, Frequency = 3 day")
# sns.kdeplot(data=pd.melt(pd.concat([test_trpo_3_15_B['cost'],test_delta_3_15_B['cost']], 
#                                              axis=1, keys=['TRPO','DELTA']), 
#                                var_name="agent",
#                                value_name="cost"), 
#                   x="cost", hue="agent", ax=ax_3_15).set(title="Cost = 1.00%, Frequency = 6 day")
# Out:
# [Text(0.5, 1.0, 'Cost = 0.75%, Frequency = 6 day')]

# %% [markdown]
# ### Plot Sample Cost Distribution for Delta vs TRPO agent

# %%
plt.figure(figsize=(10,7))
sns.kdeplot(data=pd.melt(pd.concat([test_trpo_0_30_B['cost'],test_delta_0_30_B['cost']], 
                                             axis=1, keys=['TRPO','DELTA']), 
                               var_name="agent",
                               value_name="cost"), 
                  x="cost", hue="agent").set(title="Cost = 0.25%, Frequency = 3 day")
# Out:
# [Text(0.5, 1.0, 'Cost = 0.25%, Frequency = 3 day')]

# %% [markdown]
# ### Cost Data Results

# %%
costdata_B = pd.DataFrame(
    {"Frequency": [90,90,90,30,30,30,15,15,15],
     "Cost": [0.25, 0.50, 0.75]*3,
    "Delta Mean Cost": [np.mean(test_delta_0_90_B['cost']),
                        np.mean(test_delta_1_90_B['cost']),
                        np.mean(test_delta_2_90_B['cost']),
                        np.mean(test_delta_0_30_B['cost']),
                        np.mean(test_delta_1_30_B['cost']),
                        np.mean(test_delta_2_30_B['cost']),
                        np.mean(test_delta_0_15_B['cost']),
                        np.mean(test_delta_1_15_B['cost']),
                        np.mean(test_delta_2_15_B['cost'])],
    "Delta SD Cost": [np.std(test_delta_0_90_B['cost']),
                        np.std(test_delta_1_90_B['cost']),
                        np.std(test_delta_2_90_B['cost']),
                        np.std(test_delta_0_30_B['cost']),
                        np.std(test_delta_1_30_B['cost']),
                        np.std(test_delta_2_30_B['cost']),
                        np.std(test_delta_0_15_B['cost']),
                        np.std(test_delta_1_15_B['cost']),
                        np.std(test_delta_2_15_B['cost'])],
    "TRPO Mean Cost": [np.mean(test_trpo_0_90_B['cost']),
                        np.mean(test_trpo_1_90_B['cost']),
                        np.mean(test_trpo_2_90_B['cost']),
                        np.mean(test_trpo_0_30_B['cost']),
                        np.mean(test_trpo_1_30_B['cost']),
                        np.mean(test_trpo_2_30_B['cost']),
                        np.mean(test_trpo_0_15_B['cost']),
                        np.mean(test_trpo_1_15_B['cost']),
                        np.mean(test_trpo_2_15_B['cost'])],
    "TRPO SD Cost": [np.std(test_trpo_0_90_B['cost']),
                        np.std(test_trpo_1_90_B['cost']),
                        np.std(test_trpo_2_90_B['cost']),
                        np.std(test_trpo_0_30_B['cost']),
                        np.std(test_trpo_1_30_B['cost']),
                        np.std(test_trpo_2_30_B['cost']),
                        np.std(test_trpo_0_15_B['cost']),
                        np.std(test_trpo_1_15_B['cost']),
                        np.std(test_trpo_2_15_B['cost'])]}
)
costdata_B["Mean Cost Improvement (%)"] = 100*(costdata_B["Delta Mean Cost"]-costdata_B["TRPO Mean Cost"])/costdata_B["Delta Mean Cost"]
costdata_B["SD Cost Improvement (%)"] = 100*(costdata_B["Delta SD Cost"]-costdata_B["TRPO SD Cost"])/costdata_B["Delta SD Cost"]
costdata_B.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_9e94b">
#   <thead>
#     <tr>
#       <th id="T_9e94b_level0_col0" class="col_heading level0 col0" >Frequency</th>
#       <th id="T_9e94b_level0_col1" class="col_heading level0 col1" >Cost</th>
#       <th id="T_9e94b_level0_col2" class="col_heading level0 col2" >Delta Mean Cost</th>
#       <th id="T_9e94b_level0_col3" class="col_heading level0 col3" >Delta SD Cost</th>
#       <th id="T_9e94b_level0_col4" class="col_heading level0 col4" >TRPO Mean Cost</th>
#       <th id="T_9e94b_level0_col5" class="col_heading level0 col5" >TRPO SD Cost</th>
#       <th id="T_9e94b_level0_col6" class="col_heading level0 col6" >Mean Cost Improvement (%)</th>
#       <th id="T_9e94b_level0_col7" class="col_heading level0 col7" >SD Cost Improvement (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9e94b_row0_col0" class="data row0 col0" >90</td>
#       <td id="T_9e94b_row0_col1" class="data row0 col1" >0.250000</td>
# ...
